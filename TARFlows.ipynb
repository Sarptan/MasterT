# %%
# tarflow.py
from __future__ import annotations
import math
from dataclasses import dataclass
from typing import Optional, Tuple, List

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
def make_causal_mask(n_tokens: int, device: torch.device) -> torch.Tensor:
    """
    Attention mask for causal self-attention.
    Shape: [n_tokens, n_tokens]
    Masked (future) positions are set to -inf.
    """
    # upper triangular (above diagonal) = future positions
    mask = torch.full((n_tokens, n_tokens), float("-inf"), device=device)
    mask = torch.triu(mask, diagonal=1)
    return mask

# %%
class TransformerBlock(nn.Module):
    """
    Minimal pre-norm Transformer block:
    LN -> MHA -> residual
    LN -> FFN -> residual
    """
    def __init__(self, d_model: int, n_heads: int, d_ff: int, dropout: float = 0.0):
        super().__init__()
        assert d_model % n_heads == 0, "d_model must be divisible by n_heads"

        self.ln1 = nn.LayerNorm(d_model)
        self.attn = nn.MultiheadAttention(
            embed_dim=d_model, num_heads=n_heads, dropout=dropout, batch_first=True
        )
        self.ln2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Linear(d_ff, d_model),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x: torch.Tensor, attn_mask: torch.Tensor) -> torch.Tensor:
        # x: [B, N, d_model], attn_mask: [N, N]
        h = self.ln1(x)
        a, _ = self.attn(h, h, h, attn_mask=attn_mask, need_weights=False)
        x = x + self.dropout(a)

        h = self.ln2(x)
        f = self.ff(h)
        x = x + self.dropout(f)
        return x

# %%
class CausalTransformer(nn.Module):
    """
    Causal Transformer over a short sequence (here N=2 tokens).
    """
    def __init__(
        self,
        n_tokens: int,
        token_dim: int,
        d_model: int = 32,
        n_heads: int = 4,
        n_layers: int = 2,
        d_ff: Optional[int] = None,
        dropout: float = 0.0,
    ):
        super().__init__()
        self.n_tokens = n_tokens
        self.token_dim = token_dim
        self.d_model = d_model

        if d_ff is None:
            d_ff = 4 * d_model

        self.in_proj = nn.Linear(token_dim, d_model)

        # learned positional embeddings (N is tiny)
        self.pos_emb = nn.Parameter(torch.zeros(n_tokens, d_model))
        nn.init.normal_(self.pos_emb, mean=0.0, std=0.02)

        self.blocks = nn.ModuleList([
            TransformerBlock(d_model=d_model, n_heads=n_heads, d_ff=d_ff, dropout=dropout)
            for _ in range(n_layers)
        ])

        self.out_ln = nn.LayerNorm(d_model)

    def forward(self, tokens: torch.Tensor) -> torch.Tensor:
        """
        tokens: [B, N, token_dim]
        returns: [B, N, d_model]
        """
        B, N, D = tokens.shape
        assert N == self.n_tokens and D == self.token_dim

        h = self.in_proj(tokens)  # [B, N, d_model]
        h = h + self.pos_emb.unsqueeze(0)  # broadcast over batch

        attn_mask = make_causal_mask(self.n_tokens, device=tokens.device)

        for blk in self.blocks:
            h = blk(h, attn_mask=attn_mask)

        h = self.out_ln(h)
        return h

# %%
class TARFlowBlock(nn.Module):
    """
    One TARFlow block for 2D:
    - optional permutation (swap dims)
    - causal transformer predicts mu and log_s per token
    - autoregressive affine transform

    We implement forward: x -> z with:
        z = (x - mu) * exp(-log_s)
        log_det = -sum(log_s)

    Inverse (sampling) is sequential in token order:
        x_i = mu_i(x_<i) + exp(log_s_i(x_<i)) * z_i
    """
    def __init__(
        self,
        dim: int = 2,
        d_model: int = 32,
        n_heads: int = 4,
        n_layers: int = 2,
        dropout: float = 0.0,
        clamp_log_s: float = 5.0,
        reverse: bool = False,
    ):
        super().__init__()
        assert dim == 2, "This TARFlowBlock implementation is specialized for dim=2 (two moons)."
        self.dim = dim
        self.n_tokens = dim         # N=2 tokens
        self.token_dim = 1          # scalar per token
        self.reverse = reverse
        self.clamp_log_s = clamp_log_s

        self.transformer = CausalTransformer(
            n_tokens=self.n_tokens,
            token_dim=self.token_dim,
            d_model=d_model,
            n_heads=n_heads,
            n_layers=n_layers,
            dropout=dropout,
        )
        self.param_head = nn.Linear(d_model, 2)  # -> (mu, log_s)

        # learned "start token" value (so token 0 params are unconditional)
        self.sos = nn.Parameter(torch.zeros(1, 1, self.token_dim))
        nn.init.normal_(self.sos, mean=0.0, std=0.02)

    def _permute(self, x: torch.Tensor) -> torch.Tensor:
        # x: [B,2]
        if not self.reverse:
            return x
        return torch.stack([x[:, 1], x[:, 0]], dim=1)

    def _unpermute(self, x: torch.Tensor) -> torch.Tensor:
        # swap back (same operation)
        return self._permute(x)

    def _tokens_from_x(self, x: torch.Tensor) -> torch.Tensor:
        """
        Build AR transformer inputs by shifting x right:
        token0 sees SOS
        token1 sees x1
        This allows params for x2 to depend on x1.
        """
        B = x.size(0)
        tokens = torch.zeros(B, 2, 1, device=x.device, dtype=x.dtype)
        tokens[:, 0:1, :] = self.sos.expand(B, -1, -1)   # token 0 = SOS
        tokens[:, 1, 0] = x[:, 0]                        # token 1 = x1 (context for x2)
        return tokens


    def _params(self, x: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:
        """
        x: [B,2] (already permuted in the block's order)
        returns mu, log_s: both [B,2]
        """
        tokens = self._tokens_from_x(x)                   # [B,2,1]
        h = self.transformer(tokens)                      # [B,2,d_model]
        params = self.param_head(h)                       # [B,2,2]
        mu = params[..., 0]                               # [B,2]
        log_s = params[..., 1].clamp(-self.clamp_log_s, self.clamp_log_s)
        return mu, log_s

    def forward(self, x: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:
        """
        x -> z
        returns:
            z: [B,2]
            log_det: [B]
        """
        x = self._permute(x)
        mu, log_s = self._params(x)

        z = (x - mu) * torch.exp(-log_s)                  # [B,2]
        log_det = (-log_s).sum(dim=1)                     # [B]

        z = self._unpermute(z)
        return z, log_det

    @torch.no_grad()
    def inverse(self, z: torch.Tensor) -> torch.Tensor:
        z = self._permute(z)
        x = torch.zeros_like(z)

        # Step 1: get params for x1 (unconditional)
        mu, log_s = self._params(x)  # token0 uses SOS
        x[:, 0] = mu[:, 0] + torch.exp(log_s[:, 0]) * z[:, 0]

        # Step 2: get params for x2 (conditioned on x1)
        mu, log_s = self._params(x)  # token1 now sees x1 via shifted tokens
        x[:, 1] = mu[:, 1] + torch.exp(log_s[:, 1]) * z[:, 1]

        x = self._unpermute(x)
        return x

# %%
class TARFlow(nn.Module):
    """
    Stack of TARFlowBlocks + standard normal base.
    """
    def __init__(
        self,
        dim: int = 2,
        n_blocks: int = 5,
        d_model: int = 32,
        n_heads: int = 4,
        n_layers: int = 2,
        dropout: float = 0.0,
        clamp_log_s: float = 5.0,
    ):
        super().__init__()
        self.dim = dim
        self.n_blocks = n_blocks

        blocks: List[nn.Module] = []
        for b in range(n_blocks):
            blocks.append(TARFlowBlock(
                dim=dim,
                d_model=d_model,
                n_heads=n_heads,
                n_layers=n_layers,
                dropout=dropout,
                clamp_log_s=clamp_log_s,
                reverse=(b % 2 == 1),   # alternate order by reversing
            ))
        self.blocks = nn.ModuleList(blocks)

    def forward(self, x: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]:
        """
        x -> z through all blocks
        returns z, total_log_det
        """
        log_det_total = torch.zeros(x.size(0), device=x.device)
        z = x
        for blk in self.blocks:
            z, log_det = blk(z)
            log_det_total = log_det_total + log_det
        return z, log_det_total

    def log_prob(self, x: torch.Tensor) -> torch.Tensor:
        """
        log p(x) = log p(z) + log|det dz/dx|
        """
        z, log_det = self.forward(x)
        # standard normal log prob
        log_base = -0.5 * (z ** 2).sum(dim=1) - 0.5 * self.dim * math.log(2 * math.pi)
        return log_base + log_det

    @torch.no_grad()
    def sample(self, n: int, device: Optional[torch.device] = None) -> torch.Tensor:
        if device is None:
            device = next(self.parameters()).device
        z = torch.randn(n, self.dim, device=device)
        x = z
        # invert blocks in reverse order
        for blk in reversed(self.blocks):
            x = blk.inverse(x)
        return x

# %%
import torch
from torch.optim import Adam

def train_flow(model, train_loader, test_loader=None, epochs=50, lr=1e-3, device="cpu"):
    model.to(device)
    opt = Adam(model.parameters(), lr=lr)

    for ep in range(1, epochs + 1):
        model.train()
        total = 0.0
        n = 0
        for x, *_ in train_loader:   # if your loader returns (x,y) just ignore y
            x = x.to(device).float()
            loss = -model.log_prob(x).mean()

            opt.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            opt.step()

            total += loss.item() * x.size(0)
            n += x.size(0)

        train_nll = total / n

        if test_loader is not None:
            model.eval()
            total = 0.0
            n = 0
            with torch.no_grad():
                for x, *_ in test_loader:
                    x = x.to(device).float()
                    loss = -model.log_prob(x).mean()
                    total += loss.item() * x.size(0)
                    n += x.size(0)
            test_nll = total / n
            print(f"Epoch {ep:03d} | Train NLL: {train_nll:.4f} | Test NLL: {test_nll:.4f}")
        else:
            print(f"Epoch {ep:03d} | Train NLL: {train_nll:.4f}")

# %%
from sklearn import datasets
import torch

def get_moons_unconditional(n_samples=5000, noise=0.1, batch_size=256, test_split=0.2, seed=42):
    X, _ = datasets.make_moons(n_samples=n_samples, noise=noise, random_state=seed)
    X = torch.tensor(X, dtype=torch.float32)

    # split
    n_test = int(test_split * n_samples)
    idx = torch.randperm(n_samples)
    test_idx = idx[:n_test]
    train_idx = idx[n_test:]

    X_train = X[train_idx]
    X_test  = X[test_idx]

    train_ds = torch.utils.data.TensorDataset(X_train)
    test_ds  = torch.utils.data.TensorDataset(X_test)

    train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    test_loader  = torch.utils.data.DataLoader(test_ds, batch_size=batch_size, shuffle=False)
    return train_loader, test_loader, X_train, X_test


def get_moons_conditional(n_samples=5000, noise=0.1, batch_size=256, test_split=0.2, seed=42):
    X, y = datasets.make_moons(n_samples=n_samples, noise=noise, random_state=seed)
    X = torch.tensor(X, dtype=torch.float32)
    y = torch.nn.functional.one_hot(torch.tensor(y), num_classes=2).float()

    # split
    n_test = int(test_split * n_samples)
    idx = torch.randperm(n_samples)
    test_idx = idx[:n_test]
    train_idx = idx[n_test:]

    X_train, y_train = X[train_idx], y[train_idx]
    X_test,  y_test  = X[test_idx],  y[test_idx]

    train_ds = torch.utils.data.TensorDataset(X_train, y_train)
    test_ds  = torch.utils.data.TensorDataset(X_test, y_test)

    train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    test_loader  = torch.utils.data.DataLoader(test_ds, batch_size=batch_size, shuffle=False)
    return train_loader, test_loader, X_train, X_test, y_train, y_test

# %%
train_loader, test_loader, X_train, X_test = get_moons_unconditional()

# X_uncond: [N,2], train_loader returns batches of x
tarflow = TARFlow(
    dim=2,
    n_blocks=5,
    d_model=64,
    n_heads=4,
    n_layers=5,
    dropout=0.0,
)

train_flow(tarflow, train_loader=train_loader, test_loader=test_loader, epochs=100, lr=1e-4, device="cpu")

samples = tarflow.sample(2000)
# Out:
# Epoch 001 | Train NLL: 2.6970 | Test NLL: 1.8836
# Epoch 002 | Train NLL: 1.8267 | Test NLL: 1.7734
# Epoch 003 | Train NLL: 1.7469 | Test NLL: 1.6203
# Epoch 004 | Train NLL: 1.8151 | Test NLL: 1.8040
# Epoch 005 | Train NLL: 1.7005 | Test NLL: 1.7247
# Epoch 006 | Train NLL: 1.5918 | Test NLL: 1.5123
# Epoch 007 | Train NLL: 1.5229 | Test NLL: 1.4709
# Epoch 008 | Train NLL: 1.4902 | Test NLL: 1.3983
# Epoch 009 | Train NLL: 1.4231 | Test NLL: 1.3912
# Epoch 010 | Train NLL: 1.3570 | Test NLL: 1.3641
# Epoch 011 | Train NLL: 1.3448 | Test NLL: 1.3626
# Epoch 012 | Train NLL: 1.3743 | Test NLL: 1.5326
# Epoch 013 | Train NLL: 1.3887 | Test NLL: 1.3115
# Epoch 014 | Train NLL: 1.3350 | Test NLL: 1.3241
# Epoch 015 | Train NLL: 1.3493 | Test NLL: 1.3785
# Epoch 016 | Train NLL: 1.3114 | Test NLL: 1.3032
# Epoch 017 | Train NLL: 1.2873 | Test NLL: 1.2640
# Epoch 018 | Train NLL: 1.2646 | Test NLL: 1.3101
# Epoch 019 | Train NLL: 1.2657 | Test NLL: 1.3478
# Epoch 020 | Train NLL: 1.2749 | Test NLL: 1.2291
# Epoch 021 | Train NLL: 1.2837 | Test NLL: 1.3132
# Epoch 022 | Train NLL: 1.2474 | Test NLL: 1.2584
# Epoch 023 | Train NLL: 1.2734 | Test NLL: 1.2510
# Epoch 024 | Train NLL: 1.2322 | Test NLL: 1.2618
# Epoch 025 | Train NLL: 1.2425 | Test NLL: 1.2129
# Epoch 026 | Train NLL: 1.2339 | Test NLL: 1.2549
# Epoch 027 | Train NLL: 1.2236 | Test NLL: 1.2063
# Epoch 028 | Train NLL: 1.2205 | Test NLL: 1.1904
# Epoch 029 | Train NLL: 1.2310 | Test NLL: 1.2586
# Epoch 030 | Train NLL: 1.2202 | Test NLL: 1.2156
# Epoch 031 | Train NLL: 1.2242 | Test NLL: 1.2337
# Epoch 032 | Train NLL: 1.2181 | Test NLL: 1.2121
# Epoch 033 | Train NLL: 1.2437 | Test NLL: 1.2534
# Epoch 034 | Train NLL: 1.2254 | Test NLL: 1.1691
# Epoch 035 | Train NLL: 1.2074 | Test NLL: 1.1669
# Epoch 036 | Train NLL: 1.1845 | Test NLL: 1.4000
# Epoch 037 | Train NLL: 1.2125 | Test NLL: 1.2177
# Epoch 038 | Train NLL: 1.2336 | Test NLL: 1.2081
# Epoch 039 | Train NLL: 1.1966 | Test NLL: 1.2214
# Epoch 040 | Train NLL: 1.2054 | Test NLL: 1.1939
# Epoch 041 | Train NLL: 1.2031 | Test NLL: 1.2375
# Epoch 042 | Train NLL: 1.1824 | Test NLL: 1.1719
# Epoch 043 | Train NLL: 1.1814 | Test NLL: 1.1470
# Epoch 044 | Train NLL: 1.2014 | Test NLL: 1.2417
# Epoch 045 | Train NLL: 1.1816 | Test NLL: 1.1588
# Epoch 046 | Train NLL: 1.1814 | Test NLL: 1.1725
# Epoch 047 | Train NLL: 1.1687 | Test NLL: 1.1286
# Epoch 048 | Train NLL: 1.1680 | Test NLL: 1.1755
# Epoch 049 | Train NLL: 1.1741 | Test NLL: 1.2446
# Epoch 050 | Train NLL: 1.1547 | Test NLL: 1.1177
# Epoch 051 | Train NLL: 1.1487 | Test NLL: 1.1686
# Epoch 052 | Train NLL: 1.1460 | Test NLL: 1.1732
# Epoch 053 | Train NLL: 1.1460 | Test NLL: 1.1843
# Epoch 054 | Train NLL: 1.1577 | Test NLL: 1.1221
# Epoch 055 | Train NLL: 1.1287 | Test NLL: 1.1705
# Epoch 056 | Train NLL: 1.1472 | Test NLL: 1.1505
# Epoch 057 | Train NLL: 1.1516 | Test NLL: 1.1638
# Epoch 058 | Train NLL: 1.1613 | Test NLL: 1.2329
# Epoch 059 | Train NLL: 1.1675 | Test NLL: 1.1230
# Epoch 060 | Train NLL: 1.1124 | Test NLL: 1.1550
# Epoch 061 | Train NLL: 1.1257 | Test NLL: 1.1139
# Epoch 062 | Train NLL: 1.1299 | Test NLL: 1.1361
# Epoch 063 | Train NLL: 1.2041 | Test NLL: 1.1796
# Epoch 064 | Train NLL: 1.1461 | Test NLL: 1.1326
# Epoch 065 | Train NLL: 1.1368 | Test NLL: 1.1322
# Epoch 066 | Train NLL: 1.1070 | Test NLL: 1.1964
# Epoch 067 | Train NLL: 1.1268 | Test NLL: 1.1463
# Epoch 068 | Train NLL: 1.1375 | Test NLL: 1.1007
# Epoch 069 | Train NLL: 1.1400 | Test NLL: 1.1139
# Epoch 070 | Train NLL: 1.0957 | Test NLL: 1.1072
# Epoch 071 | Train NLL: 1.1333 | Test NLL: 1.1157
# Epoch 072 | Train NLL: 1.1325 | Test NLL: 1.1188
# Epoch 073 | Train NLL: 1.1338 | Test NLL: 1.0834
# Epoch 074 | Train NLL: 1.1230 | Test NLL: 1.1153
# Epoch 075 | Train NLL: 1.1074 | Test NLL: 1.0953
# Epoch 076 | Train NLL: 1.1354 | Test NLL: 1.1686
# Epoch 077 | Train NLL: 1.1543 | Test NLL: 1.1348
# Epoch 078 | Train NLL: 1.1296 | Test NLL: 1.1280
# Epoch 079 | Train NLL: 1.1383 | Test NLL: 1.1222
# Epoch 080 | Train NLL: 1.1421 | Test NLL: 1.1084
# Epoch 081 | Train NLL: 1.1175 | Test NLL: 1.1282
# Epoch 082 | Train NLL: 1.1246 | Test NLL: 1.1337
# Epoch 083 | Train NLL: 1.1312 | Test NLL: 1.3451
# Epoch 084 | Train NLL: 1.1623 | Test NLL: 1.1188
# Epoch 085 | Train NLL: 1.0967 | Test NLL: 1.1146
# Epoch 086 | Train NLL: 1.1312 | Test NLL: 1.1110
# Epoch 087 | Train NLL: 1.1055 | Test NLL: 1.1530
# Epoch 088 | Train NLL: 1.1324 | Test NLL: 1.1403
# Epoch 089 | Train NLL: 1.1138 | Test NLL: 1.1805
# Epoch 090 | Train NLL: 1.1345 | Test NLL: 1.1014
# Epoch 091 | Train NLL: 1.1106 | Test NLL: 1.0789
# Epoch 092 | Train NLL: 1.0929 | Test NLL: 1.0927
# Epoch 093 | Train NLL: 1.1120 | Test NLL: 1.1411
# Epoch 094 | Train NLL: 1.1195 | Test NLL: 1.1162
# Epoch 095 | Train NLL: 1.1047 | Test NLL: 1.1450
# Epoch 096 | Train NLL: 1.1042 | Test NLL: 1.1108
# Epoch 097 | Train NLL: 1.1017 | Test NLL: 1.1049
# Epoch 098 | Train NLL: 1.1125 | Test NLL: 1.1330
# Epoch 099 | Train NLL: 1.1079 | Test NLL: 1.0769
# Epoch 100 | Train NLL: 1.1362 | Test NLL: 1.1267

# %%
tarflow.eval()

with torch.no_grad():
    gen_X = tarflow.sample(2000).cpu()

# %%
import matplotlib.pyplot as plt

def plot_moons(real_X, gen_X, title_suffix=""):
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))

    # Real data
    axes[0].scatter(
        real_X[:, 0], real_X[:, 1],
        s=10, alpha=0.6
    )
    axes[0].set_title(f"Real Two Moons {title_suffix}")
    axes[0].set_aspect("equal")

    # Generated data
    axes[1].scatter(
        gen_X[:, 0], gen_X[:, 1],
        s=10, alpha=0.6
    )
    axes[1].set_title(f"TARFlow Samples {title_suffix}")
    axes[1].set_aspect("equal")

    for ax in axes:
        ax.set_xlim(-2.5, 2.5)
        ax.set_ylim(-1.5, 2.0)
        ax.grid(alpha=0.2)

    plt.tight_layout()
    plt.show()

# %%
plot_moons(X_train, gen_X)

# %%
import time
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F

def count_params(model):
    return sum(p.numel() for p in model.parameters())

@torch.no_grad()
def eval_nll(model, dataloader, device=None):
    """
    Works with:
      - flow models that return (z, log_det) via model(x) or model(x,y)
      - TARFlow-style models that implement .log_prob(x) (or .log_prob(x,y) if you add conditional later)
    Returns average NLL (lower is better).
    """
    model.eval()
    if device is None:
        device = next(model.parameters()).device

    total_nll = 0.0
    total_n = 0

    for batch in dataloader:
        x = batch[0].to(device)

        # TARFlow path: if model has log_prob
        if hasattr(model, "log_prob"):
            # unconditional
            lp = model.log_prob(x)   # [B]
            nll = (-lp)
        else:
            # your existing path: model returns (z, log_det)
            D = x.shape[1]
            const = 0.5 * D * torch.log(torch.tensor(2 * torch.pi, device=device))

            if getattr(model, "condition_size", None) is not None:
                y = batch[1].to(device)
                z, log_det = model(x, y)
            else:
                z, log_det = model(x)

            nll = const + 0.5 * torch.sum(z**2, dim=1) - log_det

        total_nll += nll.sum().item()
        total_n += x.size(0)

    return total_nll / total_n


def _rbf_kernel(x, y, sigma):
    x_norm = (x**2).sum(dim=1, keepdim=True)
    y_norm = (y**2).sum(dim=1, keepdim=True).t()
    dist2 = x_norm + y_norm - 2.0 * x @ y.t()
    return torch.exp(-dist2 / (2.0 * sigma**2))

@torch.no_grad()
def mmd_rbf(x, y, sigma=None, max_pts=1000):
    x = x.detach()
    y = y.detach()

    if sigma is None:
        z = torch.cat([x, y], dim=0)
        if z.size(0) > max_pts:
            idx = torch.randperm(z.size(0))[:max_pts]
            z = z[idx]
        z_norm = (z**2).sum(dim=1, keepdim=True)
        dist2 = z_norm + z_norm.t() - 2.0 * z @ z.t()
        dist2 = dist2[torch.triu(torch.ones_like(dist2), diagonal=1) == 1]
        median_dist = torch.sqrt(torch.median(dist2).clamp(min=1e-12))
        sigma = median_dist.item()

    Kxx = _rbf_kernel(x, x, sigma)
    Kyy = _rbf_kernel(y, y, sigma)
    Kxy = _rbf_kernel(x, y, sigma)

    n = x.size(0)
    m = y.size(0)
    if n > 1:
        Kxx = Kxx - torch.diag(torch.diag(Kxx))
        mmd_xx = Kxx.sum() / (n * (n - 1))
    else:
        mmd_xx = 0.0

    if m > 1:
        Kyy = Kyy - torch.diag(torch.diag(Kyy))
        mmd_yy = Kyy.sum() / (m * (m - 1))
    else:
        mmd_yy = 0.0

    mmd_xy = Kxy.mean()
    return float((mmd_xx + mmd_yy - 2.0 * mmd_xy).item())

@torch.no_grad()
def sampling_speed(model, sample_fn, n_samples=2000, n_repeats=20, warmup=5):
    model.eval()
    for _ in range(warmup):
        _ = sample_fn(n_samples)

    t0 = time.perf_counter()
    for _ in range(n_repeats):
        _ = sample_fn(n_samples)
    t1 = time.perf_counter()

    total = n_samples * n_repeats
    return total / (t1 - t0)

# %%
device = next(tarflow.parameters()).device

def sample_tarflow_uncond(n):
    return tarflow.sample(n, device=device).to(device)

# %%
train_loader, uncond_test_loader, X_train, X_test_uncond = get_moons_unconditional()


rows = []

# TARFlow (unconditional)
nll = eval_nll(tarflow, uncond_test_loader, device=device)
gen = sample_tarflow_uncond(2000)
mmd = mmd_rbf(gen, X_test_uncond.to(device)[:2000])
sps = sampling_speed(tarflow, sample_tarflow_uncond, n_samples=2000)

rows.append({
    "Model": "TARFlow (uncond)",
    "Params": count_params(tarflow),
    "Test NLL ↓": nll,
    "MMD² ↓": mmd,
    "Sampling (samples/s) ↑": sps
})

tarflow_df = pd.DataFrame(rows)
tarflow_df
# Out:
#               Model   Params  Test NLL ↓    MMD² ↓  Sampling (samples/s) ↑
# 0  TARFlow (uncond)  1252175    1.109912  0.001814             4392.649205

# %%
import pandas as pd
import torch

def run_tarflow_ablation(configs, train_loader, test_loader, X_test, device="cpu",
                         epochs=100, lr=1e-3, n_gen=2000):
    rows = []

    for cfg in configs:
        name = cfg["name"]
        model = TARFlow(
            dim=2,
            n_blocks=cfg["n_blocks"],
            d_model=cfg["d_model"],
            n_heads=cfg["n_heads"],
            n_layers=cfg["n_layers"],
            dropout=cfg.get("dropout", 0.0),
            clamp_log_s=cfg.get("clamp_log_s", 5.0),
        ).to(device)

        train_flow(model, train_loader, test_loader, epochs=epochs, lr=lr, device=device)

        # evaluation
        nll = eval_nll(model, test_loader, device=device)

        def sample_fn(n):
            return model.sample(n, device=torch.device(device))

        gen = sample_fn(n_gen).to(device)
        mmd = mmd_rbf(gen, X_test.to(device)[:n_gen])
        sps = sampling_speed(model, sample_fn, n_samples=n_gen)

        rows.append({
            "Model": name,
            "Params": count_params(model),
            "Test NLL ↓": nll,
            "MMD² ↓": mmd,
            "Sampling (samples/s) ↑": sps
        })

    return pd.DataFrame(rows)

# %%
configs = [
    {"name": "TARFlow-S (B=5, dm=16, L=1, H=2)", "n_blocks": 5, "d_model": 16, "n_layers": 1, "n_heads": 2},
    {"name": "TARFlow-M (B=5, dm=32, L=2, H=4)", "n_blocks": 5, "d_model": 32, "n_layers": 2, "n_heads": 4},
    {"name": "TARFlow-L (B=5, dm=64, L=4, H=8)", "n_blocks": 5, "d_model": 64, "n_layers": 4, "n_heads": 8},

    {"name": "TARFlow-M-2B (B=2, dm=32, L=2, H=4)", "n_blocks": 2, "d_model": 32, "n_layers": 2, "n_heads": 4},
    {"name": "TARFlow-M-10B (B=10, dm=32, L=2, H=4)", "n_blocks": 10, "d_model": 32, "n_layers": 2, "n_heads": 4},
]

# %%
train_loader, test_loader, X_train, X_test = get_moons_unconditional(
    n_samples=5000, noise=0.1, batch_size=256, test_split=0.2, seed=42
)
device = "cuda" if torch.cuda.is_available() else "cpu"

tarflow_df = run_tarflow_ablation(
    configs, train_loader, test_loader, X_test, device=device, epochs=100, lr=1e-3
)
tarflow_df
# Out:
# Epoch 001 | Train NLL: 2.2496 | Test NLL: 1.7424
# Epoch 002 | Train NLL: 1.6675 | Test NLL: 1.6480
# Epoch 003 | Train NLL: 1.6163 | Test NLL: 1.5796
# Epoch 004 | Train NLL: 1.5448 | Test NLL: 1.6061
# Epoch 005 | Train NLL: 1.5446 | Test NLL: 1.5409
# Epoch 006 | Train NLL: 1.4710 | Test NLL: 1.4647
# Epoch 007 | Train NLL: 1.4320 | Test NLL: 1.4494
# Epoch 008 | Train NLL: 1.4200 | Test NLL: 1.4326
# Epoch 009 | Train NLL: 1.4240 | Test NLL: 1.4843
# Epoch 010 | Train NLL: 1.4138 | Test NLL: 1.4158
# Epoch 011 | Train NLL: 1.3767 | Test NLL: 1.4069
# Epoch 012 | Train NLL: 1.4085 | Test NLL: 1.4272
# Epoch 013 | Train NLL: 1.3600 | Test NLL: 1.3865
# Epoch 014 | Train NLL: 1.4053 | Test NLL: 1.4319
# Epoch 015 | Train NLL: 1.3734 | Test NLL: 1.3714
# Epoch 016 | Train NLL: 1.3748 | Test NLL: 1.3425
# Epoch 017 | Train NLL: 1.3569 | Test NLL: 1.3465
# Epoch 018 | Train NLL: 1.3087 | Test NLL: 1.3019
# Epoch 019 | Train NLL: 1.2783 | Test NLL: 1.2931
# Epoch 020 | Train NLL: 1.3014 | Test NLL: 1.2711
# Epoch 021 | Train NLL: 1.2835 | Test NLL: 1.4704
# Epoch 022 | Train NLL: 1.2707 | Test NLL: 1.3312
# Epoch 023 | Train NLL: 1.2711 | Test NLL: 1.4963
# Epoch 024 | Train NLL: 1.3696 | Test NLL: 1.3446
# Epoch 025 | Train NLL: 1.2539 | Test NLL: 1.2539
# Epoch 026 | Train NLL: 1.2414 | Test NLL: 1.2220
# Epoch 027 | Train NLL: 1.2181 | Test NLL: 1.3398
# Epoch 028 | Train NLL: 1.2249 | Test NLL: 1.3156
# Epoch 029 | Train NLL: 1.2543 | Test NLL: 1.2094
# Epoch 030 | Train NLL: 1.2167 | Test NLL: 1.4216
# Epoch 031 | Train NLL: 1.2424 | Test NLL: 1.2117
# Epoch 032 | Train NLL: 1.2593 | Test NLL: 1.2845
# Epoch 033 | Train NLL: 1.3204 | Test NLL: 1.2430
# Epoch 034 | Train NLL: 1.2070 | Test NLL: 1.2343
# Epoch 035 | Train NLL: 1.1998 | Test NLL: 1.2197
# Epoch 036 | Train NLL: 1.2123 | Test NLL: 1.2041
# Epoch 037 | Train NLL: 1.2241 | Test NLL: 1.2178
# Epoch 038 | Train NLL: 1.2030 | Test NLL: 1.4232
# Epoch 039 | Train NLL: 1.2101 | Test NLL: 1.2059
# Epoch 040 | Train NLL: 1.2079 | Test NLL: 1.2888
# Epoch 041 | Train NLL: 1.2246 | Test NLL: 1.2027
# Epoch 042 | Train NLL: 1.2056 | Test NLL: 1.2244
# Epoch 043 | Train NLL: 1.1888 | Test NLL: 1.1996
# Epoch 044 | Train NLL: 1.1986 | Test NLL: 1.2082
# Epoch 045 | Train NLL: 1.1792 | Test NLL: 1.3659
# Epoch 046 | Train NLL: 1.2631 | Test NLL: 1.2747
# Epoch 047 | Train NLL: 1.2172 | Test NLL: 1.2789
# Epoch 048 | Train NLL: 1.1818 | Test NLL: 1.2019
# Epoch 049 | Train NLL: 1.2137 | Test NLL: 1.2400
# Epoch 050 | Train NLL: 1.2431 | Test NLL: 1.3405
# Epoch 051 | Train NLL: 1.2318 | Test NLL: 1.1890
# Epoch 052 | Train NLL: 1.1952 | Test NLL: 1.2083
# Epoch 053 | Train NLL: 1.1950 | Test NLL: 1.2084
# Epoch 054 | Train NLL: 1.2023 | Test NLL: 1.2338
# Epoch 055 | Train NLL: 1.2393 | Test NLL: 1.1884
# Epoch 056 | Train NLL: 1.2174 | Test NLL: 1.3051
# Epoch 057 | Train NLL: 1.2480 | Test NLL: 1.2216
# Epoch 058 | Train NLL: 1.2107 | Test NLL: 1.1838
# Epoch 059 | Train NLL: 1.2184 | Test NLL: 1.3745
# Epoch 060 | Train NLL: 1.2256 | Test NLL: 1.2053
# Epoch 061 | Train NLL: 1.1797 | Test NLL: 1.4425
# Epoch 062 | Train NLL: 1.2324 | Test NLL: 1.2887
# Epoch 063 | Train NLL: 1.2056 | Test NLL: 1.2019
# Epoch 064 | Train NLL: 1.1838 | Test NLL: 1.2100
# Epoch 065 | Train NLL: 1.1852 | Test NLL: 1.2018
# Epoch 066 | Train NLL: 1.1859 | Test NLL: 1.2551
# Epoch 067 | Train NLL: 1.1748 | Test NLL: 1.2107
# Epoch 068 | Train NLL: 1.2079 | Test NLL: 1.2120
# Epoch 069 | Train NLL: 1.1853 | Test NLL: 1.1764
# Epoch 070 | Train NLL: 1.2081 | Test NLL: 1.1597
# Epoch 071 | Train NLL: 1.2144 | Test NLL: 1.1614
# Epoch 072 | Train NLL: 1.1631 | Test NLL: 1.3380
# Epoch 073 | Train NLL: 1.1772 | Test NLL: 1.1974
# Epoch 074 | Train NLL: 1.1572 | Test NLL: 1.2140
# Epoch 075 | Train NLL: 1.1831 | Test NLL: 1.2479
# Epoch 076 | Train NLL: 1.1773 | Test NLL: 1.1762
# Epoch 077 | Train NLL: 1.1700 | Test NLL: 1.1620
# Epoch 078 | Train NLL: 1.1529 | Test NLL: 1.1684
# Epoch 079 | Train NLL: 1.1496 | Test NLL: 1.1555
# Epoch 080 | Train NLL: 1.1610 | Test NLL: 1.2008
# Epoch 081 | Train NLL: 1.2087 | Test NLL: 1.1986
# Epoch 082 | Train NLL: 1.1530 | Test NLL: 1.2504
# Epoch 083 | Train NLL: 1.1766 | Test NLL: 1.2444
# Epoch 084 | Train NLL: 1.1781 | Test NLL: 1.1801
# Epoch 085 | Train NLL: 1.1673 | Test NLL: 1.1739
# Epoch 086 | Train NLL: 1.1769 | Test NLL: 1.1800
# Epoch 087 | Train NLL: 1.1629 | Test NLL: 1.2060
# Epoch 088 | Train NLL: 1.1523 | Test NLL: 1.1983
# Epoch 089 | Train NLL: 1.1991 | Test NLL: 1.2034
# Epoch 090 | Train NLL: 1.1896 | Test NLL: 1.1550
# Epoch 091 | Train NLL: 1.1440 | Test NLL: 1.1536
# Epoch 092 | Train NLL: 1.1582 | Test NLL: 1.1636
# Epoch 093 | Train NLL: 1.1400 | Test NLL: 1.1678
# Epoch 094 | Train NLL: 1.1494 | Test NLL: 1.1651
# Epoch 095 | Train NLL: 1.1493 | Test NLL: 1.2168
# Epoch 096 | Train NLL: 1.1804 | Test NLL: 1.1617
# Epoch 097 | Train NLL: 1.1595 | Test NLL: 1.2367
# Epoch 098 | Train NLL: 1.1635 | Test NLL: 1.1562
# Epoch 099 | Train NLL: 1.1819 | Test NLL: 1.2227
# Epoch 100 | Train NLL: 1.1925 | Test NLL: 1.1651
# Epoch 001 | Train NLL: 4.1855 | Test NLL: 1.9340
# Epoch 002 | Train NLL: 1.9723 | Test NLL: 1.8070
# Epoch 003 | Train NLL: 1.7572 | Test NLL: 1.7109
# Epoch 004 | Train NLL: 1.6921 | Test NLL: 1.6461
# Epoch 005 | Train NLL: 1.6822 | Test NLL: 1.6478
# Epoch 006 | Train NLL: 1.6397 | Test NLL: 1.6437
# Epoch 007 | Train NLL: 1.6761 | Test NLL: 1.5558
# Epoch 008 | Train NLL: 1.5965 | Test NLL: 1.5280
# Epoch 009 | Train NLL: 1.5304 | Test NLL: 1.5037
# Epoch 010 | Train NLL: 1.5253 | Test NLL: 1.4768
# Epoch 011 | Train NLL: 1.4781 | Test NLL: 1.5736
# Epoch 012 | Train NLL: 1.4974 | Test NLL: 1.4082
# Epoch 013 | Train NLL: 1.4168 | Test NLL: 1.4728
# Epoch 014 | Train NLL: 1.4002 | Test NLL: 1.4565
# Epoch 015 | Train NLL: 1.3976 | Test NLL: 1.3383
# Epoch 016 | Train NLL: 1.3903 | Test NLL: 1.3616
# Epoch 017 | Train NLL: 1.4721 | Test NLL: 1.5547
# Epoch 018 | Train NLL: 1.5013 | Test NLL: 1.5391
# Epoch 019 | Train NLL: 1.3562 | Test NLL: 1.3115
# Epoch 020 | Train NLL: 1.3213 | Test NLL: 1.2722
# Epoch 021 | Train NLL: 1.3530 | Test NLL: 1.4971
# Epoch 022 | Train NLL: 1.4098 | Test NLL: 1.3623
# Epoch 023 | Train NLL: 1.3323 | Test NLL: 1.3002
# Epoch 024 | Train NLL: 1.3419 | Test NLL: 1.3600
# Epoch 025 | Train NLL: 1.3384 | Test NLL: 1.4125
# Epoch 026 | Train NLL: 1.3339 | Test NLL: 1.2538
# Epoch 027 | Train NLL: 1.3140 | Test NLL: 1.3192
# Epoch 028 | Train NLL: 1.3148 | Test NLL: 1.3074
# Epoch 029 | Train NLL: 1.2765 | Test NLL: 1.2429
# Epoch 030 | Train NLL: 1.3181 | Test NLL: 1.2418
# Epoch 031 | Train NLL: 1.2304 | Test NLL: 1.2392
# Epoch 032 | Train NLL: 1.2514 | Test NLL: 1.3666
# Epoch 033 | Train NLL: 1.3458 | Test NLL: 1.3130
# Epoch 034 | Train NLL: 1.2872 | Test NLL: 1.2407
# Epoch 035 | Train NLL: 1.2407 | Test NLL: 1.2917
# Epoch 036 | Train NLL: 1.2542 | Test NLL: 1.2388
# Epoch 037 | Train NLL: 1.2743 | Test NLL: 1.4165
# Epoch 038 | Train NLL: 1.2598 | Test NLL: 1.2189
# Epoch 039 | Train NLL: 1.2199 | Test NLL: 1.2165
# Epoch 040 | Train NLL: 1.2277 | Test NLL: 1.2318
# Epoch 041 | Train NLL: 1.2198 | Test NLL: 1.2227
# Epoch 042 | Train NLL: 1.2290 | Test NLL: 1.2719
# Epoch 043 | Train NLL: 1.2313 | Test NLL: 1.3099
# Epoch 044 | Train NLL: 1.2574 | Test NLL: 1.2516
# Epoch 045 | Train NLL: 1.2110 | Test NLL: 1.2075
# Epoch 046 | Train NLL: 1.1908 | Test NLL: 1.2242
# Epoch 047 | Train NLL: 1.2043 | Test NLL: 1.2737
# Epoch 048 | Train NLL: 1.1946 | Test NLL: 1.2183
# Epoch 049 | Train NLL: 1.1935 | Test NLL: 1.2329
# Epoch 050 | Train NLL: 1.2339 | Test NLL: 1.2270
# Epoch 051 | Train NLL: 1.2044 | Test NLL: 1.2461
# Epoch 052 | Train NLL: 1.2840 | Test NLL: 1.3167
# Epoch 053 | Train NLL: 1.2652 | Test NLL: 1.2877
# Epoch 054 | Train NLL: 1.2928 | Test NLL: 1.3501
# Epoch 055 | Train NLL: 1.1896 | Test NLL: 1.1819
# Epoch 056 | Train NLL: 1.1871 | Test NLL: 1.2291
# Epoch 057 | Train NLL: 1.1864 | Test NLL: 1.2096
# Epoch 058 | Train NLL: 1.1957 | Test NLL: 1.2659
# Epoch 059 | Train NLL: 1.1941 | Test NLL: 1.1819
# Epoch 060 | Train NLL: 1.1644 | Test NLL: 1.2425
# Epoch 061 | Train NLL: 1.2132 | Test NLL: 1.3189
# Epoch 062 | Train NLL: 1.2020 | Test NLL: 1.1475
# Epoch 063 | Train NLL: 1.1573 | Test NLL: 1.2544
# Epoch 064 | Train NLL: 1.2042 | Test NLL: 1.2241
# Epoch 065 | Train NLL: 1.1791 | Test NLL: 1.1537
# Epoch 066 | Train NLL: 1.1564 | Test NLL: 1.1481
# Epoch 067 | Train NLL: 1.1386 | Test NLL: 1.1799
# Epoch 068 | Train NLL: 1.1364 | Test NLL: 1.1401
# Epoch 069 | Train NLL: 1.1426 | Test NLL: 1.1693
# Epoch 070 | Train NLL: 1.1692 | Test NLL: 1.1623
# Epoch 071 | Train NLL: 1.1874 | Test NLL: 1.1872
# Epoch 072 | Train NLL: 1.1647 | Test NLL: 1.2309
# Epoch 073 | Train NLL: 1.1856 | Test NLL: 1.2602
# Epoch 074 | Train NLL: 1.2282 | Test NLL: 1.1742
# Epoch 075 | Train NLL: 1.2004 | Test NLL: 1.1756
# Epoch 076 | Train NLL: 1.1754 | Test NLL: 1.1964
# Epoch 077 | Train NLL: 1.1896 | Test NLL: 1.1698
# Epoch 078 | Train NLL: 1.1602 | Test NLL: 1.1648
# Epoch 079 | Train NLL: 1.1377 | Test NLL: 1.1772
# Epoch 080 | Train NLL: 1.1813 | Test NLL: 1.2640
# Epoch 081 | Train NLL: 1.1635 | Test NLL: 1.4038
# Epoch 082 | Train NLL: 1.1844 | Test NLL: 1.2073
# Epoch 083 | Train NLL: 1.1569 | Test NLL: 1.1501
# Epoch 084 | Train NLL: 1.1554 | Test NLL: 1.1482
# Epoch 085 | Train NLL: 1.1297 | Test NLL: 1.1350
# Epoch 086 | Train NLL: 1.1518 | Test NLL: 1.2075
# Epoch 087 | Train NLL: 1.2154 | Test NLL: 1.2091
# Epoch 088 | Train NLL: 1.1941 | Test NLL: 1.1520
# Epoch 089 | Train NLL: 1.1735 | Test NLL: 1.1649
# Epoch 090 | Train NLL: 1.1378 | Test NLL: 1.1578
# Epoch 091 | Train NLL: 1.1675 | Test NLL: 1.1166
# Epoch 092 | Train NLL: 1.1702 | Test NLL: 1.2030
# Epoch 093 | Train NLL: 1.1622 | Test NLL: 1.1944
# Epoch 094 | Train NLL: 1.1343 | Test NLL: 1.2323
# Epoch 095 | Train NLL: 1.1525 | Test NLL: 1.1635
# Epoch 096 | Train NLL: 1.1707 | Test NLL: 1.1495
# Epoch 097 | Train NLL: 1.1486 | Test NLL: 1.2306
# Epoch 098 | Train NLL: 1.1873 | Test NLL: 1.1717
# Epoch 099 | Train NLL: 1.1444 | Test NLL: 1.2061
# Epoch 100 | Train NLL: 1.1670 | Test NLL: 1.1704
# Epoch 001 | Train NLL: 34.2201 | Test NLL: 3.4805
# Epoch 002 | Train NLL: 2.3360 | Test NLL: 1.9714
# Epoch 003 | Train NLL: 1.9306 | Test NLL: 1.8359
# Epoch 004 | Train NLL: 1.7715 | Test NLL: 1.6742
# Epoch 005 | Train NLL: 1.7056 | Test NLL: 1.7881
# Epoch 006 | Train NLL: 1.7058 | Test NLL: 1.7326
# Epoch 007 | Train NLL: 1.6616 | Test NLL: 1.5930
# Epoch 008 | Train NLL: 1.5646 | Test NLL: 1.4926
# Epoch 009 | Train NLL: 1.5481 | Test NLL: 1.5864
# Epoch 010 | Train NLL: 1.5361 | Test NLL: 1.6394
# Epoch 011 | Train NLL: 1.5266 | Test NLL: 1.4683
# Epoch 012 | Train NLL: 1.4513 | Test NLL: 1.5022
# Epoch 013 | Train NLL: 1.3996 | Test NLL: 1.4786
# Epoch 014 | Train NLL: 1.4080 | Test NLL: 1.3486
# Epoch 015 | Train NLL: 1.5426 | Test NLL: 1.4225
# Epoch 016 | Train NLL: 1.4689 | Test NLL: 1.6161
# Epoch 017 | Train NLL: 1.4980 | Test NLL: 1.4068
# Epoch 018 | Train NLL: 1.4595 | Test NLL: 1.4846
# Epoch 019 | Train NLL: 1.5042 | Test NLL: 1.4402
# Epoch 020 | Train NLL: 1.3416 | Test NLL: 1.3781
# Epoch 021 | Train NLL: 1.3791 | Test NLL: 1.3813
# Epoch 022 | Train NLL: 1.4823 | Test NLL: 1.4623
# Epoch 023 | Train NLL: 1.5464 | Test NLL: 1.4277
# Epoch 024 | Train NLL: 1.4104 | Test NLL: 1.7110
# Epoch 025 | Train NLL: 1.4618 | Test NLL: 1.2970
# Epoch 026 | Train NLL: 1.3216 | Test NLL: 1.3332
# Epoch 027 | Train NLL: 1.2949 | Test NLL: 1.3629
# Epoch 028 | Train NLL: 1.4255 | Test NLL: 1.2160
# Epoch 029 | Train NLL: 1.2964 | Test NLL: 1.2799
# Epoch 030 | Train NLL: 1.4224 | Test NLL: 1.4335
# Epoch 031 | Train NLL: 1.3589 | Test NLL: 1.4559
# Epoch 032 | Train NLL: 1.3219 | Test NLL: 1.3043
# Epoch 033 | Train NLL: 1.2898 | Test NLL: 1.4916
# Epoch 034 | Train NLL: 1.3780 | Test NLL: 1.8532
# Epoch 035 | Train NLL: 1.4105 | Test NLL: 1.3765
# Epoch 036 | Train NLL: 1.3458 | Test NLL: 1.4276
# Epoch 037 | Train NLL: 1.3011 | Test NLL: 1.3374
# Epoch 038 | Train NLL: 1.3188 | Test NLL: 1.4818
# Epoch 039 | Train NLL: 1.3318 | Test NLL: 1.2507
# Epoch 040 | Train NLL: 1.2598 | Test NLL: 1.2600
# Epoch 041 | Train NLL: 1.2434 | Test NLL: 1.3227
# Epoch 042 | Train NLL: 1.2991 | Test NLL: 1.3816
# Epoch 043 | Train NLL: 1.3168 | Test NLL: 1.4013
# Epoch 044 | Train NLL: 1.3586 | Test NLL: 1.3020
# Epoch 045 | Train NLL: 1.2817 | Test NLL: 1.3338
# Epoch 046 | Train NLL: 1.3227 | Test NLL: 1.3203
# Epoch 047 | Train NLL: 1.2976 | Test NLL: 1.2949
# Epoch 048 | Train NLL: 1.2620 | Test NLL: 1.3671
# Epoch 049 | Train NLL: 1.2881 | Test NLL: 1.2686
# Epoch 050 | Train NLL: 1.2729 | Test NLL: 1.2229
# Epoch 051 | Train NLL: 1.2391 | Test NLL: 1.2298
# Epoch 052 | Train NLL: 1.2311 | Test NLL: 1.3202
# Epoch 053 | Train NLL: 1.3985 | Test NLL: 1.2517
# Epoch 054 | Train NLL: 1.2106 | Test NLL: 1.2510
# Epoch 055 | Train NLL: 1.2092 | Test NLL: 1.3139
# Epoch 056 | Train NLL: 1.2902 | Test NLL: 1.2248
# Epoch 057 | Train NLL: 1.3811 | Test NLL: 1.2912
# Epoch 058 | Train NLL: 1.2124 | Test NLL: 1.4264
# Epoch 059 | Train NLL: 1.2314 | Test NLL: 1.2425
# Epoch 060 | Train NLL: 1.2614 | Test NLL: 1.3044
# Epoch 061 | Train NLL: 1.2905 | Test NLL: 1.4105
# Epoch 062 | Train NLL: 1.2902 | Test NLL: 1.4538
# Epoch 063 | Train NLL: 1.3541 | Test NLL: 1.2410
# Epoch 064 | Train NLL: 1.3370 | Test NLL: 1.2699
# Epoch 065 | Train NLL: 1.3052 | Test NLL: 1.3004
# Epoch 066 | Train NLL: 1.2042 | Test NLL: 1.2835
# Epoch 067 | Train NLL: 1.2402 | Test NLL: 1.2253
# Epoch 068 | Train NLL: 1.2537 | Test NLL: 1.2216
# Epoch 069 | Train NLL: 1.1931 | Test NLL: 1.2598
# Epoch 070 | Train NLL: 1.2504 | Test NLL: 1.2674
# Epoch 071 | Train NLL: 1.2409 | Test NLL: 1.2707
# Epoch 072 | Train NLL: 1.2035 | Test NLL: 1.3341
# Epoch 073 | Train NLL: 1.3489 | Test NLL: 1.3542
# Epoch 074 | Train NLL: 1.2228 | Test NLL: 1.2765
# Epoch 075 | Train NLL: 1.2292 | Test NLL: 1.2792
# Epoch 076 | Train NLL: 1.2240 | Test NLL: 1.2033
# Epoch 077 | Train NLL: 1.2373 | Test NLL: 1.3410
# Epoch 078 | Train NLL: 1.2801 | Test NLL: 1.2769
# Epoch 079 | Train NLL: 1.2468 | Test NLL: 1.2495
# Epoch 080 | Train NLL: 1.2336 | Test NLL: 1.2852
# Epoch 081 | Train NLL: 1.1876 | Test NLL: 1.1974
# Epoch 082 | Train NLL: 1.2520 | Test NLL: 1.3688
# Epoch 083 | Train NLL: 1.2937 | Test NLL: 1.2284
# Epoch 084 | Train NLL: 1.2137 | Test NLL: 1.1888
# Epoch 085 | Train NLL: 1.3030 | Test NLL: 1.2596
# Epoch 086 | Train NLL: 1.2217 | Test NLL: 1.2696
# Epoch 087 | Train NLL: 1.1860 | Test NLL: 1.2500
# Epoch 088 | Train NLL: 1.2180 | Test NLL: 1.3040
# Epoch 089 | Train NLL: 1.2509 | Test NLL: 1.2457
# Epoch 090 | Train NLL: 1.1891 | Test NLL: 1.1841
# Epoch 091 | Train NLL: 1.1802 | Test NLL: 1.2290
# Epoch 092 | Train NLL: 1.2285 | Test NLL: 1.2147
# Epoch 093 | Train NLL: 1.1949 | Test NLL: 1.2118
# Epoch 094 | Train NLL: 1.2057 | Test NLL: 1.3957
# Epoch 095 | Train NLL: 1.3408 | Test NLL: 1.2806
# Epoch 096 | Train NLL: 1.2003 | Test NLL: 1.2072
# Epoch 097 | Train NLL: 1.2062 | Test NLL: 1.1948
# Epoch 098 | Train NLL: 1.1802 | Test NLL: 1.2824
# Epoch 099 | Train NLL: 1.2090 | Test NLL: 1.5049
# Epoch 100 | Train NLL: 1.3317 | Test NLL: 1.3405
# Epoch 001 | Train NLL: 2.1931 | Test NLL: 1.9440
# Epoch 002 | Train NLL: 1.8797 | Test NLL: 1.7851
# Epoch 003 | Train NLL: 1.7448 | Test NLL: 1.7004
# Epoch 004 | Train NLL: 1.6746 | Test NLL: 1.6621
# Epoch 005 | Train NLL: 1.6323 | Test NLL: 1.6663
# Epoch 006 | Train NLL: 1.6559 | Test NLL: 1.6659
# Epoch 007 | Train NLL: 1.6119 | Test NLL: 1.6052
# Epoch 008 | Train NLL: 1.5959 | Test NLL: 1.6870
# Epoch 009 | Train NLL: 1.6475 | Test NLL: 1.6317
# Epoch 010 | Train NLL: 1.6141 | Test NLL: 1.6419
# Epoch 011 | Train NLL: 1.5957 | Test NLL: 1.5986
# Epoch 012 | Train NLL: 1.5819 | Test NLL: 1.6009
# Epoch 013 | Train NLL: 1.5800 | Test NLL: 1.6103
# Epoch 014 | Train NLL: 1.5732 | Test NLL: 1.5940
# Epoch 015 | Train NLL: 1.5575 | Test NLL: 1.6475
# Epoch 016 | Train NLL: 1.6040 | Test NLL: 1.6368
# Epoch 017 | Train NLL: 1.5478 | Test NLL: 1.5581
# Epoch 018 | Train NLL: 1.5348 | Test NLL: 1.5520
# Epoch 019 | Train NLL: 1.5249 | Test NLL: 1.5513
# Epoch 020 | Train NLL: 1.5282 | Test NLL: 1.5513
# Epoch 021 | Train NLL: 1.5149 | Test NLL: 1.5304
# Epoch 022 | Train NLL: 1.5135 | Test NLL: 1.5182
# Epoch 023 | Train NLL: 1.5279 | Test NLL: 1.5399
# Epoch 024 | Train NLL: 1.4739 | Test NLL: 1.4395
# Epoch 025 | Train NLL: 1.4026 | Test NLL: 1.3926
# Epoch 026 | Train NLL: 1.3820 | Test NLL: 1.3595
# Epoch 027 | Train NLL: 1.3219 | Test NLL: 1.3168
# Epoch 028 | Train NLL: 1.2944 | Test NLL: 1.2674
# Epoch 029 | Train NLL: 1.2816 | Test NLL: 1.3497
# Epoch 030 | Train NLL: 1.3057 | Test NLL: 1.2628
# Epoch 031 | Train NLL: 1.2576 | Test NLL: 1.2467
# Epoch 032 | Train NLL: 1.2739 | Test NLL: 1.2539
# Epoch 033 | Train NLL: 1.2685 | Test NLL: 1.2613
# Epoch 034 | Train NLL: 1.2842 | Test NLL: 1.3307
# Epoch 035 | Train NLL: 1.2855 | Test NLL: 1.3251
# Epoch 036 | Train NLL: 1.2891 | Test NLL: 1.2584
# Epoch 037 | Train NLL: 1.2743 | Test NLL: 1.2642
# Epoch 038 | Train NLL: 1.2499 | Test NLL: 1.2557
# Epoch 039 | Train NLL: 1.2635 | Test NLL: 1.4083
# Epoch 040 | Train NLL: 1.3101 | Test NLL: 1.2654
# Epoch 041 | Train NLL: 1.2830 | Test NLL: 1.2836
# Epoch 042 | Train NLL: 1.2504 | Test NLL: 1.2766
# Epoch 043 | Train NLL: 1.2630 | Test NLL: 1.2544
# Epoch 044 | Train NLL: 1.2290 | Test NLL: 1.2402
# Epoch 045 | Train NLL: 1.2506 | Test NLL: 1.2824
# Epoch 046 | Train NLL: 1.2429 | Test NLL: 1.2287
# Epoch 047 | Train NLL: 1.2362 | Test NLL: 1.2059
# Epoch 048 | Train NLL: 1.2261 | Test NLL: 1.2107
# Epoch 049 | Train NLL: 1.2624 | Test NLL: 1.2932
# Epoch 050 | Train NLL: 1.3091 | Test NLL: 1.2416
# Epoch 051 | Train NLL: 1.2491 | Test NLL: 1.2436
# Epoch 052 | Train NLL: 1.2606 | Test NLL: 1.2399
# Epoch 053 | Train NLL: 1.2427 | Test NLL: 1.2096
# Epoch 054 | Train NLL: 1.2268 | Test NLL: 1.2308
# Epoch 055 | Train NLL: 1.2487 | Test NLL: 1.2094
# Epoch 056 | Train NLL: 1.2466 | Test NLL: 1.2387
# Epoch 057 | Train NLL: 1.2485 | Test NLL: 1.2847
# Epoch 058 | Train NLL: 1.2390 | Test NLL: 1.3248
# Epoch 059 | Train NLL: 1.2467 | Test NLL: 1.2396
# Epoch 060 | Train NLL: 1.2242 | Test NLL: 1.2222
# Epoch 061 | Train NLL: 1.2194 | Test NLL: 1.2811
# Epoch 062 | Train NLL: 1.2332 | Test NLL: 1.2449
# Epoch 063 | Train NLL: 1.2182 | Test NLL: 1.2194
# Epoch 064 | Train NLL: 1.2155 | Test NLL: 1.2800
# Epoch 065 | Train NLL: 1.2590 | Test NLL: 1.2611
# Epoch 066 | Train NLL: 1.2445 | Test NLL: 1.2273
# Epoch 067 | Train NLL: 1.2221 | Test NLL: 1.2426
# Epoch 068 | Train NLL: 1.2230 | Test NLL: 1.2327
# Epoch 069 | Train NLL: 1.2167 | Test NLL: 1.2427
# Epoch 070 | Train NLL: 1.2251 | Test NLL: 1.2770
# Epoch 071 | Train NLL: 1.2417 | Test NLL: 1.2462
# Epoch 072 | Train NLL: 1.2362 | Test NLL: 1.2015
# Epoch 073 | Train NLL: 1.2435 | Test NLL: 1.2527
# Epoch 074 | Train NLL: 1.2618 | Test NLL: 1.2215
# Epoch 075 | Train NLL: 1.2175 | Test NLL: 1.2234
# Epoch 076 | Train NLL: 1.2144 | Test NLL: 1.2088
# Epoch 077 | Train NLL: 1.2036 | Test NLL: 1.2209
# Epoch 078 | Train NLL: 1.2246 | Test NLL: 1.2111
# Epoch 079 | Train NLL: 1.2386 | Test NLL: 1.2591
# Epoch 080 | Train NLL: 1.2327 | Test NLL: 1.2762
# Epoch 081 | Train NLL: 1.2498 | Test NLL: 1.2322
# Epoch 082 | Train NLL: 1.2146 | Test NLL: 1.2055
# Epoch 083 | Train NLL: 1.2109 | Test NLL: 1.2280
# Epoch 084 | Train NLL: 1.2425 | Test NLL: 1.2117
# Epoch 085 | Train NLL: 1.2153 | Test NLL: 1.1876
# Epoch 086 | Train NLL: 1.2125 | Test NLL: 1.1965
# Epoch 087 | Train NLL: 1.2141 | Test NLL: 1.2620
# Epoch 088 | Train NLL: 1.2416 | Test NLL: 1.2769
# Epoch 089 | Train NLL: 1.3244 | Test NLL: 1.2551
# Epoch 090 | Train NLL: 1.2188 | Test NLL: 1.2721
# Epoch 091 | Train NLL: 1.2317 | Test NLL: 1.1868
# Epoch 092 | Train NLL: 1.2107 | Test NLL: 1.2067
# Epoch 093 | Train NLL: 1.2153 | Test NLL: 1.1818
# Epoch 094 | Train NLL: 1.2094 | Test NLL: 1.1768
# Epoch 095 | Train NLL: 1.2106 | Test NLL: 1.1998
# Epoch 096 | Train NLL: 1.2014 | Test NLL: 1.2263
# Epoch 097 | Train NLL: 1.2076 | Test NLL: 1.1993
# Epoch 098 | Train NLL: 1.2174 | Test NLL: 1.2488
# Epoch 099 | Train NLL: 1.2112 | Test NLL: 1.2216
# Epoch 100 | Train NLL: 1.1964 | Test NLL: 1.2072
# Epoch 001 | Train NLL: 6.7054 | Test NLL: 3.0955
# Epoch 002 | Train NLL: 2.1940 | Test NLL: 1.7508
# Epoch 003 | Train NLL: 1.8008 | Test NLL: 1.9452
# Epoch 004 | Train NLL: 1.8764 | Test NLL: 1.8064
# Epoch 005 | Train NLL: 1.6865 | Test NLL: 1.5888
# Epoch 006 | Train NLL: 1.6696 | Test NLL: 1.5821
# Epoch 007 | Train NLL: 1.6125 | Test NLL: 1.6191
# Epoch 008 | Train NLL: 1.5201 | Test NLL: 1.4686
# Epoch 009 | Train NLL: 1.5455 | Test NLL: 1.7894
# Epoch 010 | Train NLL: 1.5863 | Test NLL: 1.7078
# Epoch 011 | Train NLL: 1.5994 | Test NLL: 1.4573
# Epoch 012 | Train NLL: 1.5527 | Test NLL: 1.4947
# Epoch 013 | Train NLL: 1.4366 | Test NLL: 1.4304
# Epoch 014 | Train NLL: 1.3985 | Test NLL: 1.3938
# Epoch 015 | Train NLL: 1.3987 | Test NLL: 1.3787
# Epoch 016 | Train NLL: 1.3851 | Test NLL: 1.3936
# Epoch 017 | Train NLL: 1.3399 | Test NLL: 1.3449
# Epoch 018 | Train NLL: 1.3239 | Test NLL: 1.3447
# Epoch 019 | Train NLL: 1.3517 | Test NLL: 1.5107
# Epoch 020 | Train NLL: 1.3201 | Test NLL: 1.2826
# Epoch 021 | Train NLL: 1.2977 | Test NLL: 1.3098
# Epoch 022 | Train NLL: 1.2874 | Test NLL: 1.3061
# Epoch 023 | Train NLL: 1.3049 | Test NLL: 2.0369
# Epoch 024 | Train NLL: 1.3841 | Test NLL: 1.3876
# Epoch 025 | Train NLL: 1.2952 | Test NLL: 1.2557
# Epoch 026 | Train NLL: 1.3306 | Test NLL: 1.2549
# Epoch 027 | Train NLL: 1.2827 | Test NLL: 1.3353
# Epoch 028 | Train NLL: 1.3452 | Test NLL: 1.2191
# Epoch 029 | Train NLL: 1.2552 | Test NLL: 1.2513
# Epoch 030 | Train NLL: 1.2699 | Test NLL: 1.2994
# Epoch 031 | Train NLL: 1.2892 | Test NLL: 1.3059
# Epoch 032 | Train NLL: 1.2300 | Test NLL: 1.2607
# Epoch 033 | Train NLL: 1.3314 | Test NLL: 1.1890
# Epoch 034 | Train NLL: 1.2585 | Test NLL: 1.1871
# Epoch 035 | Train NLL: 1.2927 | Test NLL: 1.3085
# Epoch 036 | Train NLL: 1.2664 | Test NLL: 1.1665
# Epoch 037 | Train NLL: 1.2523 | Test NLL: 1.2045
# Epoch 038 | Train NLL: 1.2499 | Test NLL: 1.1953
# Epoch 039 | Train NLL: 1.2268 | Test NLL: 1.1865
# Epoch 040 | Train NLL: 1.3191 | Test NLL: 1.1987
# Epoch 041 | Train NLL: 1.2672 | Test NLL: 1.2528
# Epoch 042 | Train NLL: 1.3573 | Test NLL: 1.2650
# Epoch 043 | Train NLL: 1.3301 | Test NLL: 1.3950
# Epoch 044 | Train NLL: 1.2556 | Test NLL: 1.3683
# Epoch 045 | Train NLL: 1.4378 | Test NLL: 1.6901
# Epoch 046 | Train NLL: 1.3972 | Test NLL: 1.3325
# Epoch 047 | Train NLL: 1.2988 | Test NLL: 1.3612
# Epoch 048 | Train NLL: 1.2660 | Test NLL: 1.2537
# Epoch 049 | Train NLL: 1.1939 | Test NLL: 1.1910
# Epoch 050 | Train NLL: 1.2136 | Test NLL: 1.2213
# Epoch 051 | Train NLL: 1.2451 | Test NLL: 1.2551
# Epoch 052 | Train NLL: 1.3134 | Test NLL: 1.2250
# Epoch 053 | Train NLL: 1.3984 | Test NLL: 1.2626
# Epoch 054 | Train NLL: 1.2337 | Test NLL: 1.2712
# Epoch 055 | Train NLL: 1.2294 | Test NLL: 1.2087
# Epoch 056 | Train NLL: 1.2081 | Test NLL: 1.1531
# Epoch 057 | Train NLL: 1.1729 | Test NLL: 1.1591
# Epoch 058 | Train NLL: 1.1975 | Test NLL: 1.2598
# Epoch 059 | Train NLL: 1.2650 | Test NLL: 1.2285
# Epoch 060 | Train NLL: 1.2069 | Test NLL: 1.1559
# Epoch 061 | Train NLL: 1.1814 | Test NLL: 1.1902
# Epoch 062 | Train NLL: 1.2020 | Test NLL: 1.1756
# Epoch 063 | Train NLL: 1.1889 | Test NLL: 1.1638
# Epoch 064 | Train NLL: 1.1688 | Test NLL: 1.1727
# Epoch 065 | Train NLL: 1.2193 | Test NLL: 1.2831
# Epoch 066 | Train NLL: 1.3081 | Test NLL: 1.2629
# Epoch 067 | Train NLL: 1.2253 | Test NLL: 1.1940
# Epoch 068 | Train NLL: 1.1832 | Test NLL: 1.2818
# Epoch 069 | Train NLL: 1.2091 | Test NLL: 1.1479
# Epoch 070 | Train NLL: 1.2185 | Test NLL: 1.4190
# Epoch 071 | Train NLL: 1.4425 | Test NLL: 1.4061
# Epoch 072 | Train NLL: 1.3325 | Test NLL: 1.6228
# Epoch 073 | Train NLL: 1.2623 | Test NLL: 1.1693
# Epoch 074 | Train NLL: 1.1793 | Test NLL: 1.2727
# Epoch 075 | Train NLL: 1.2389 | Test NLL: 1.2581
# Epoch 076 | Train NLL: 1.2307 | Test NLL: 1.2163
# Epoch 077 | Train NLL: 1.1655 | Test NLL: 1.1476
# Epoch 078 | Train NLL: 1.1818 | Test NLL: 1.2025
# Epoch 079 | Train NLL: 1.2283 | Test NLL: 1.2475
# Epoch 080 | Train NLL: 1.1673 | Test NLL: 1.1631
# Epoch 081 | Train NLL: 1.1633 | Test NLL: 1.1546
# Epoch 082 | Train NLL: 1.1837 | Test NLL: 1.1619
# Epoch 083 | Train NLL: 1.1691 | Test NLL: 1.5603
# Epoch 084 | Train NLL: 1.2393 | Test NLL: 1.1710
# Epoch 085 | Train NLL: 1.1673 | Test NLL: 1.3324
# Epoch 086 | Train NLL: 1.2995 | Test NLL: 1.1562
# Epoch 087 | Train NLL: 1.1986 | Test NLL: 1.2868
# Epoch 088 | Train NLL: 1.2698 | Test NLL: 1.5307
# Epoch 089 | Train NLL: 1.2842 | Test NLL: 1.2852
# Epoch 090 | Train NLL: 1.1704 | Test NLL: 1.1573
# Epoch 091 | Train NLL: 1.1541 | Test NLL: 1.1874
# Epoch 092 | Train NLL: 1.2138 | Test NLL: 1.3372
# Epoch 093 | Train NLL: 1.2248 | Test NLL: 1.1731
# Epoch 094 | Train NLL: 1.2105 | Test NLL: 1.1592
# Epoch 095 | Train NLL: 1.3283 | Test NLL: 1.2622
# Epoch 096 | Train NLL: 1.2396 | Test NLL: 1.3305
# Epoch 097 | Train NLL: 1.2183 | Test NLL: 1.1389
# Epoch 098 | Train NLL: 1.1928 | Test NLL: 1.1814
# Epoch 099 | Train NLL: 1.2039 | Test NLL: 1.1714
# Epoch 100 | Train NLL: 1.1490 | Test NLL: 1.1512
#                                    Model   Params  Test NLL ↓    MMD² ↓  \
# 0       TARFlow-S (B=5, dm=16, L=1, H=2)    17055    1.165137  0.000074
# 1       TARFlow-M (B=5, dm=32, L=2, H=4)   128335    1.170369  0.003095
# 2       TARFlow-L (B=5, dm=64, L=4, H=8)  1002255    1.340538  0.005110
# 3    TARFlow-M-2B (B=2, dm=32, L=2, H=4)    51334    1.207217  0.001154
# 4  TARFlow-M-10B (B=10, dm=32, L=2, H=4)   256670    1.151187  0.001463
#
#    Sampling (samples/s) ↑
# 0            33207.934638
# 1            12613.710233
# 2             2583.406656
# 3            27175.384428
# 4             5504.040110
